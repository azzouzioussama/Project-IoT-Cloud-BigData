# %%
from pymongo import MongoClient
import pandas as pd

# Connect to MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['your_database']  # Replace with your database name
collection = db['your_collection']  # Replace with your collection name

# %%
# Retrieve all documents from the collection
documents = collection.find()

# Convert the documents into a pandas DataFrame
test = pd.DataFrame(list(documents))

# Optionally, drop the '_id' column if you don't need it
if '_id' in test.columns:
    test.drop('_id', axis=1, inplace=True)

# %%
# Define the new column names
new_column_names = [
    'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
    'Class', 'Flight Distance', 'Inflight wifi service',
    'Departure/Arrival time convenient', 'Ease of Online booking',
    'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
    'Inflight entertainment', 'On-board service', 'Leg room service',
    'Baggage handling', 'Checkin service', 'Inflight service',
    'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
    'satisfaction'
]

# Rename the columns of the DataFrame
test.columns = new_column_names

# %%
test.head()
# Out:
#        id  Gender  Customer Type  Age  Type of Travel     Class  \
# 0  121478      31            0.0    1               5       Eco
# 1  122937      26           25.0    4               4  Business
# 2   25269      16            0.0    4               1  Business
# 3  116643      22            0.0    5               3  Business
# 4   48451      24            0.0    1               3       Eco
#
#    Flight Distance Inflight wifi service  Departure/Arrival time convenient  \
# 0                5        Loyal Customer                                  3
# 1                4        Loyal Customer                                  5
# 2                3        Loyal Customer                                  5
# 3                5     disloyal Customer                                  0
# 4                1     disloyal Customer                                  4
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# 0                       0  ...                    Male                 5
# 1                      20  ...                  Female                 4
# 2                       0  ...                    Male                 3
# 3                       0  ...                  Female                 5
# 4                       0  ...                    Male                 1
#
#    Leg room service  Baggage handling Checkin service  Inflight service  \
# 0                 5                 3               1                 5
# 1                 4                 4               2                 5
# 2                 3                 3               5                 1
# 3                 5                 5               5                 3
# 4                 3                 4               4                 1
#
#    Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0            3     neutral or dissatisfied                         5
# 1            4                   satisfied                         4
# 2            3     neutral or dissatisfied                         3
# 3            5                   satisfied                         5
# 4            4                   satisfied                         1
#
#       satisfaction
# 0  Personal Travel
# 1  Business travel
# 2  Business travel
# 3  Business travel
# 4  Business travel
#
# [5 rows x 24 columns]

# %%
train = pd.read_csv('data/train.csv')
train.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# 2                                  2  ...                       5
# 3                                  5  ...                       2
# 4                                  3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      18.0  neutral or dissatisfied
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# 4                       0.0                satisfied
#
# [5 rows x 25 columns]

# %%
# drop the first column
train.drop('Unnamed: 0', axis=1, inplace=True)
train.head()
# Out:
#        id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# 0                       3  ...                       5                 4
# 1                       3  ...                       1                 1
# 2                       2  ...                       5                 4
# 3                       5  ...                       2                 2
# 4                       3  ...                       3                 3
#
#    Leg room service  Baggage handling  Checkin service  Inflight service  \
# 0                 3                 4                4                 5
# 1                 5                 3                1                 4
# 2                 3                 4                4                 4
# 3                 5                 3                1                 4
# 4                 4                 4                3                 3
#
#    Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0            5                          25                      18.0
# 1            1                           1                       6.0
# 2            5                           0                       0.0
# 3            2                          11                       9.0
# 4            3                           0                       0.0
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied
#
# [5 rows x 24 columns]

# %%
# compare the columns of the two DataFrames
print('Columns in train: ', train.columns)
print('Columns in test: ', test.columns)
# Out:
# Columns in train:  Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')
# Columns in test:  Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
# check the shape of the two DataFrames
print('Shape of train: ', train.shape)
print('Shape of test: ', test.shape)
# Out:
# Shape of train:  (103904, 24)
# Shape of test:  (25976, 24)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# Assuming `df` is your DataFrame and `target` is your target variable
X = df.drop(columns=[target])
y = df[target]

# Encode categorical variables
encoder = OneHotEncoder()
X_encoded = encoder.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Impute the missing values
imputer = SimpleImputer(strategy='mean')
X_train_imputed = imputer.fit_transform(X_train)
X_test_imputed = imputer.transform(X_test)

# Create the model
knn = KNeighborsClassifier(n_neighbors=3)

# Train the model
knn.fit(X_train_imputed, y_train)

# Make predictions
predictions = knn.predict(X_test_imputed)
predictions[:5]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 10
#       8 imputer = SimpleImputer(strategy='mean')
#       9 train_imputed = imputer.fit_transform(train_encoded)
# ---> 10 test_imputed = imputer.transform(test_encoded)
#      12 # Train the model
#      13 knn.fit(train_imputed, train.iloc[:, -1])
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File ~/.local/lib/python3.10/site-packages/sklearn/impute/_base.py:549, in SimpleImputer.transform(self, X)
#     534 """Impute all missing values in `X`.
#     535
#     536 Parameters
#    (...)
#     545     `X` with imputed values.
#     546 """
#     547 check_is_fitted(self)
# --> 549 X = self._validate_input(X, in_fit=False)
#     550 statistics = self.statistics_
#     552 if X.shape[1] != statistics.shape[0]:
#
# File ~/.local/lib/python3.10/site-packages/sklearn/impute/_base.py:339, in SimpleImputer._validate_input(self, X, in_fit)
#     337         raise new_ve from None
#     338     else:
# --> 339         raise ve
#     341 if in_fit:
#     342     # Use the dtype seen in `fit` for non-`fit` conversion
#     343     self._fit_dtype = X.dtype
#
# File ~/.local/lib/python3.10/site-packages/sklearn/impute/_base.py:322, in SimpleImputer._validate_input(self, X, in_fit)
#     319     force_all_finite = True
#     321 try:
# --> 322     X = self._validate_data(
#     323         X,
#     324         reset=in_fit,
#     325         accept_sparse="csc",
#     326         dtype=dtype,
#     327         force_all_finite=force_all_finite,
#     328         copy=self.copy,
#     329     )
#     330 except ValueError as ve:
#     331     if "could not convert" in str(ve):
#
# File ~/.local/lib/python3.10/site-packages/sklearn/base.py:608, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     537 def _validate_data(
#     538     self,
#     539     X="no_validation",
#    (...)
#     544     **check_params,
#     545 ):
#     546     """Validate input data and set or check the `n_features_in_` attribute.
#     547
#     548     Parameters
#    (...)
#     606         validated.
#     607     """
# --> 608     self._check_feature_names(X, reset=reset)
#     610     if y is None and self._get_tags()["requires_y"]:
#     611         raise ValueError(
#     612             f"This {self.__class__.__name__} estimator "
#     613             "requires y to be passed, but the target y is None."
#     614         )
#
# File ~/.local/lib/python3.10/site-packages/sklearn/base.py:535, in BaseEstimator._check_feature_names(self, X, reset)
#     530 if not missing_names and not unexpected_names:
#     531     message += (
#     532         "Feature names must be in the same order as they were in fit.\n"
#     533     )
# --> 535 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - Customer Type
# - Departure Delay in Minutes_neutral or dissatisfied
# - Departure Delay in Minutes_satisfied
# - Gender
# - Inflight entertainment_Female
# - ...
# Feature names seen at fit time, yet now missing:
# - Customer Type_Loyal Customer
# - Customer Type_disloyal Customer
# - Departure Delay in Minutes
# - Gender_Female
# - Gender_Male
# - ...

# %%
# Impute the missing values in test data
imputer = SimpleImputer(strategy='mean')
test_imputed = imputer.transform(test)

# Make predictions
predictions = knn.predict(test_imputed)
